# %%
import pandas as pd

# %%
df = pd.read_csv("phone_dataset .csv")

# %%
df.head()
# Out:
#   device_id brand                 model        network_technology  \
# 0      A001  Acer         Iconia Talk S          GSM / HSPA / LTE
# 1      A002  Acer        Liquid Z6 Plus          GSM / HSPA / LTE
# 2      A003  Acer             Liquid Z6          GSM / HSPA / LTE
# 3      A004  Acer  Iconia Tab 10 A3-A40  No cellular connectivity
# 4      A005  Acer             Liquid X2          GSM / HSPA / LTE
#
#                                             2G_bands  \
# 0        GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 1  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 2  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 3                                                N/A
# 4                       GSM 850 / 900 / 1800 / 1900
#
#                                    3G_bands  \
# 0                  HSDPA 850 / 1900 / 2100
# 1                                     HSDPA
# 2                                     HSDPA
# 3                                       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8631 entries, 0 to 8630
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   device_id           8631 non-null   object
#  1   brand               8631 non-null   object
#  2   model               8631 non-null   object
#  3   network_technology  8631 non-null   object
#  4   2G_bands            8631 non-null   object
#  5   3G_bands            4858 non-null   object
#  6   4G_bands            1605 non-null   object
#  7   network_speed       4885 non-null   object
#  8   GPRS                8599 non-null   object
#  9   EDGE                8608 non-null   object
#  10  announced           8616 non-null   object
#  11  status              8631 non-null   object
#  12  dimentions          8612 non-null   object
#  13  weight_g            7682 non-null   object
#  14  weight_oz           7682 non-null   object
# ...

# %%
df.describe()
# Out:
#        device_id    brand model network_technology  \
# count       8631     8631  8631               8631
# unique      8631      108  8275                 38
# top         A001  Samsung   A10                GSM
# freq           1     1105     5               3507
#
#                             2G_bands           3G_bands 4G_bands  \
# count                           8631               4858     1605
# unique                           209                579      627
# top     GSM 850 / 900 / 1800 / 1900   HSDPA 900 / 2100       LTE
# freq                            2257               1115      173
#
#               network_speed  GPRS  EDGE  ...   GPS  NFC radio           USB  \
# count                  4885  8599  8608  ...  8602  795  8535          7728
# unique                  195    53    51  ...    96   51    97           101
# top     HSPA 21.1/5.76 Mbps   Yes   Yes  ...    No  Yes    No  microUSB 2.0
# ...

# %%
employees = pd.read_csv("employees.csv")

# %%
employees.head()
# Out:
#   employee device
# 0    E1234   A002
# 1    E1235   A007
# 2    E1236  A0012
# 3    E1237  A0017
# 4    E1238  A0022

# %%
df.head()
# Out:
#   device_id brand                 model        network_technology  \
# 0      A001  Acer         Iconia Talk S          GSM / HSPA / LTE
# 1      A002  Acer        Liquid Z6 Plus          GSM / HSPA / LTE
# 2      A003  Acer             Liquid Z6          GSM / HSPA / LTE
# 3      A004  Acer  Iconia Tab 10 A3-A40  No cellular connectivity
# 4      A005  Acer             Liquid X2          GSM / HSPA / LTE
#
#                                             2G_bands  \
# 0        GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 1  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 2  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 3                                                N/A
# 4                       GSM 850 / 900 / 1800 / 1900
#
#                                    3G_bands  \
# 0                  HSDPA 850 / 1900 / 2100
# 1                                     HSDPA
# 2                                     HSDPA
# 3                                       NaN
# ...

# %%
df['brand']
# Out:
# 0       Acer
# 1       Acer
# 2       Acer
# 3       Acer
# 4       Acer
#         ...
# 8626     ZTE
# 8627     ZTE
# 8628     ZTE
# 8629     ZTE
# 8630     ZTE
# Name: brand, Length: 8631, dtype: object

# %%
df.iloc[2,1] #iloc = integer location
# Out:
# 'Acer'

# %%
df.iloc[2,:]
# Out:
# device_id                                                          A003
# brand                                                              Acer
# model                                                         Liquid Z6
# network_technology                                     GSM / HSPA / LTE
# 2G_bands              GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 3G_bands                                                          HSDPA
# 4G_bands                                                            LTE
# network_speed                                                 HSPA  LTE
# GPRS                                                                Yes
# EDGE                                                                Yes
# announced                                                  2016  August
# status                               Available. Released 2016  December
# dimentions                                                            -
# ...

# %%
df[(df['brand']=='Acer') & (df['3G_bands'].str.lstrip() == 'HSDPA')]
# Out:
#    device_id brand                  model network_technology  \
# 1       A002  Acer         Liquid Z6 Plus   GSM / HSPA / LTE
# 2       A003  Acer              Liquid Z6   GSM / HSPA / LTE
# 6       A007  Acer       Liquid Zest Plus   GSM / HSPA / LTE
# 10      A011  Acer            Liquid Z330   GSM / HSPA / LTE
# 11      A012  Acer            Liquid Z320         GSM / HSPA
# 13      A014  Acer            Liquid Z630   GSM / HSPA / LTE
# 14      A015  Acer           Liquid Z530S   GSM / HSPA / LTE
# 15      A016  Acer            Liquid Z530   GSM / HSPA / LTE
# 16      A017  Acer            Liquid M330   GSM / HSPA / LTE
# 17      A018  Acer            Liquid M320         GSM / HSPA
# 35      A036  Acer    Iconia Tab 7 A1-713         GSM / HSPA
# 36      A037  Acer  Iconia Tab 7 A1-713HD         GSM / HSPA
# 38      A039  Acer     Liquid E3 Duo Plus         GSM / HSPA
# 39      A040  Acer              Liquid E3         GSM / HSPA
# ...

# %%
df['3G_bands'].str.lstrip()
# Out:
# 0                       HSDPA 850 / 1900 / 2100
# 1                                          HSDPA
# 2                                          HSDPA
# 3                                            NaN
# 4       HSDPA 900 / 1900 / 2100 - Europe| Taiwan
#                           ...
# 8626                     UMTS 850 / 1900 / 2100
# 8627                     UMTS 850 / 1900 / 2100
# 8628                     UMTS 850 / 1900 / 2100
# 8629                     UMTS 850 / 1900 / 2100
# 8630                                         NaN
# Name: 3G_bands, Length: 8631, dtype: object

# %%
employees.head()
# Out:
#   employee device
# 0    E1234   A002
# 1    E1235   A007
# 2    E1236  A0012
# 3    E1237  A0017
# 4    E1238  A0022

# %%
df.head()
# Out:
#   device_id brand                 model        network_technology  \
# 0      A001  Acer         Iconia Talk S          GSM / HSPA / LTE
# 1      A002  Acer        Liquid Z6 Plus          GSM / HSPA / LTE
# 2      A003  Acer             Liquid Z6          GSM / HSPA / LTE
# 3      A004  Acer  Iconia Tab 10 A3-A40  No cellular connectivity
# 4      A005  Acer             Liquid X2          GSM / HSPA / LTE
#
#                                             2G_bands  \
# 0        GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 1  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 2  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 3                                                N/A
# 4                       GSM 850 / 900 / 1800 / 1900
#
#                                    3G_bands  \
# 0                  HSDPA 850 / 1900 / 2100
# 1                                     HSDPA
# 2                                     HSDPA
# 3                                       NaN
# ...

# %%
employees.merge(df, left_on='device', 
                right_on='device_id', 
                how='left')[['employee', 'device', 'brand']]
# Out:
#    employee device brand
# 0     E1234   A002  Acer
# 1     E1235   A007  Acer
# 2     E1236  A0012   NaN
# 3     E1237  A0017   NaN
# 4     E1238  A0022   NaN
# 5     E1239  A0027   NaN
# 6     E1240  A0032   NaN
# 7     E1241  A0037   NaN
# 8     E1242  A0042   NaN
# 9     E1243  A0047   NaN
# 10    E1244  A0052   NaN
# 11    E1245  A0057   NaN

# %%
employees.head()
# Out:
#   employee device
# 0    E1234   A002
# 1    E1235   A007
# 2    E1236  A0012
# 3    E1237  A0017
# 4    E1238  A0022

# %%
my_devices = employees['device'].values

# %%
my_devices
# Out:
# array(['A002', 'A007', 'A0012', 'A0017', 'A0022', 'A0027', 'A0032',
#        'A0037', 'A0042', 'A0047', 'A0052', 'A0057'], dtype=object)

# %% [markdown]
# # This is a heading
#
# This notebook is very **interesting**.
#
# - Item 1
# - Item 2
# - Item 3
